# %% [markdown]
# # Introduction to COVID-19

# %% [markdown]
# Covid 19 ANAYLYSIS USING RNN AND PREDICTING EFFECTS OF IT

# %%
#importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#LOADING THE DATASET
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
X = pd.read_csv('C:/Users/miren/Downloads/COVID-19/covid_19_data.csv')

# %%
print(X.shape)
# Out:
# (306429, 8)

# %% [markdown]
# Printing different attributes, just to visulaize them and see the details

# %%
print(X.dtypes)
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
X.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0
# 5       26.0     0.0        0.0
# 6        2.0     0.0        0.0
# 7        1.0     0.0        0.0
# 8        4.0     0.0        0.0
# 9        1.0     0.0        0.0

# %%
#converting the columns into correct form 
X['ObservationDate'] = pd.to_datetime(X['ObservationDate'])
X['Last Update'] = pd.to_datetime(X['Last Update'])
print(X.dtypes)
# Out:
# SNo                         int64
# ObservationDate    datetime64[ns]
# Province/State             object
# Country/Region             object
# Last Update        datetime64[ns]
# Confirmed                 float64
# Deaths                    float64
# Recovered                 float64
# dtype: object

# %% [markdown]
# # **TEN MOST AFFECTED COUNTRIES DURING DIFFERENT MONTHS**

# %%
#made a new dataset by extracting the obeservation date
#by selecting the observation date as the end of each month the entire data for the month is selected 
#grouped them according to country of region 
#only the confirmed cases was extracted 
#sum of each month using .sum()
#took only the first 10 countries and sorted the total no of confirmed cases in each country in non-ascending order 

First_Month = X[X['ObservationDate']=='01/31/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Second_Month = X[X['ObservationDate']=='02/29/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Third_Month = X[X['ObservationDate']=='03/31/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Fourth_Month = X[X['ObservationDate']=='04/30/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Fifth_Month = X[X['ObservationDate']=='05/30/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Sixth_Month = X[X['ObservationDate']=='06/30/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
Seventh_Month = X[X['ObservationDate']=='07/30/2020'].groupby('Country/Region')['Confirmed'].sum().head(10).sort_values(ascending = False)

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 4, figsize = (20,10))
#fig.tight_layout uses to seperate each of the given subplots so that there is no overlapment 
fig.tight_layout(pad=5.0)

ax[0,0].bar(First_Month.index,First_Month)
ax[0,0].set_xticklabels(First_Month.index,rotation = 45)
ax[0,0].title.set_text('January')

ax[0,1].bar(Second_Month.index,Second_Month, color = 'g')
ax[0,1].set_xticklabels(Second_Month.index,rotation = 45)
ax[0,1].title.set_text('February')

ax[0,2].bar(Third_Month.index,Third_Month, color = 'c')
ax[0,2].set_xticklabels(Third_Month.index,rotation = 45)
ax[0,2].title.set_text('March')

ax[0,3].bar(Fourth_Month.index,Fourth_Month, color = 'r')
ax[0,3].set_xticklabels(Fourth_Month.index,rotation = 45)
ax[0,3].title.set_text('April')

ax[1,0].bar(Fifth_Month.index,Fifth_Month)
ax[1,0].set_xticklabels(Fifth_Month.index,rotation = 45)
ax[1,0].title.set_text('May')

ax[1,1].bar(Sixth_Month.index,Sixth_Month, color = 'g')
ax[1,1].set_xticklabels(Sixth_Month.index,rotation = 45)
ax[1,1].title.set_text('June')

ax[1,2].bar(Seventh_Month.index,Seventh_Month, color = 'c')
ax[1,2].set_xticklabels(Third_Month.index,rotation = 45)
ax[1,2].title.set_text('July')

plt.show()
# Out:
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
# C:\Users\miren\anaconda3\envs\DBA300\lib\site-packages\ipykernel_launcher.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # Covid-19 Data Analysis in India

# %%
Confirmed_cases = X[X['Country/Region']=='India'].groupby('ObservationDate')['Confirmed'].sum()
Deaths_cases = X[X['Country/Region']=='India'].groupby('ObservationDate')['Deaths'].sum()
Recovered_cases = X[X['Country/Region']=='India'].groupby('ObservationDate')['Recovered'].sum()

# %%
plt.figure(figsize = (20,10))
plt.plot(Confirmed_cases,color = 'c',marker = 'v',label = 'Confirmed_cases')
plt.plot(Deaths_cases,color = 'g',marker = 'x',label = 'Deaths')
plt.plot(Recovered_cases,color = 'b',marker = 'o',label = 'Recovered')
plt.xlabel('Covid-19 Cases count')
plt.ylabel('total No of Affected people')
plt.legend
plt.show()

# %% [markdown]
# # Forecasting Using RNN

# %% [markdown]
# The reason for not using ARIMA model is because ARIMA models are mainly used for linear models.
# By using RNN models, we can predict more complex patterns from the dataset

# %%
#sorting out the data
X_India = X[X['Country/Region']=='India']
arranged_dataset = X_India.groupby(['ObservationDate']).agg({'Confirmed':'sum','Recovered':'sum','Deaths':'sum'})

# %%
arranged_dataset.tail(15)
arranged_dataset.shape
# Out:
# (486, 3)

# %%
training_set = arranged_dataset.iloc[:,0:1].values

#Date Preprocessing
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

#Creating data structure with 45 timesteps 
X_train = []
y_train = []
for i in range(45,180):
    X_train.append(training_set_scaled[i-45:i, 0])
    y_train.append(training_set_scaled[i, 0])
    
X_train, y_train = np.array(X_train) , np.array(y_train)   

#Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

#Initialize the RNN
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

regressor = Sequential()

#Add first LSTM layer and Dropout regularisation
regressor.add(LSTM(units =50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

#Adding second layer
regressor.add(LSTM(units =50, return_sequences = True))
regressor.add(Dropout(0.2))

#Adding third layer
regressor.add(LSTM(units =50, return_sequences = True))
regressor.add(Dropout(0.2))

#Adding fourth layer
regressor.add(LSTM(units =50))
regressor.add(Dropout(0.2))

#Output layer
regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mse')

#Training the model
#Taking a small batch size because the number of data points to train on is limited
regressor.fit(X_train, y_train, epochs = 50, batch_size = 5)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 20s 86ms/step - loss: 1.9171e-04
# Epoch 2/50
# 27/27 [==============================] - 2s 91ms/step - loss: 4.0517e-05
# Epoch 3/50
# 27/27 [==============================] - 2s 89ms/step - loss: 2.5173e-05
# Epoch 4/50
# 27/27 [==============================] - 2s 78ms/step - loss: 2.3138e-05
# Epoch 5/50
# 27/27 [==============================] - 2s 91ms/step - loss: 1.0977e-05
# Epoch 6/50
# 27/27 [==============================] - 2s 88ms/step - loss: 1.2070e-05
# Epoch 7/50
# 27/27 [==============================] - 2s 74ms/step - loss: 7.6033e-06
# Epoch 8/50
# 27/27 [==============================] - 2s 83ms/step - loss: 1.8944e-05
# Epoch 9/50
# 27/27 [==============================] - 2s 90ms/step - loss: 9.6348e-06
# Epoch 10/50
# 27/27 [==============================] - 2s 89ms/step - loss: 1.4176e-05
# Epoch 11/50
# 27/27 [==============================] - 2s 87ms/step - loss: 1.1486e-05
# Epoch 12/50
# 27/27 [==============================] - 2s 87ms/step - loss: 9.2919e-06
# Epoch 13/50
# 27/27 [==============================] - 2s 87ms/step - loss: 1.8854e-05
# Epoch 14/50
# 27/27 [==============================] - 2s 72ms/step - loss: 8.1187e-06
# Epoch 15/50
# 27/27 [==============================] - 2s 79ms/step - loss: 8.7023e-06
# Epoch 16/50
# 27/27 [==============================] - 2s 88ms/step - loss: 1.2446e-05
# Epoch 17/50
# 27/27 [==============================] - 2s 89ms/step - loss: 4.2994e-06
# Epoch 18/50
# 27/27 [==============================] - 2s 89ms/step - loss: 6.1201e-06
# Epoch 19/50
# 27/27 [==============================] - 2s 92ms/step - loss: 6.9672e-06
# Epoch 20/50
# 27/27 [==============================] - 2s 89ms/step - loss: 1.1505e-05
# Epoch 21/50
# 27/27 [==============================] - 2s 72ms/step - loss: 2.0348e-05
# Epoch 22/50
# 27/27 [==============================] - 2s 83ms/step - loss: 6.8503e-06
# Epoch 23/50
# 27/27 [==============================] - 2s 89ms/step - loss: 1.8074e-05
# Epoch 24/50
# 27/27 [==============================] - 2s 86ms/step - loss: 1.4681e-05
# Epoch 25/50
# 27/27 [==============================] - 2s 88ms/step - loss: 1.5437e-05
# Epoch 26/50
# 27/27 [==============================] - 2s 87ms/step - loss: 1.2224e-05
# Epoch 27/50
# 27/27 [==============================] - 2s 87ms/step - loss: 8.9091e-06
# Epoch 28/50
# 27/27 [==============================] - 2s 72ms/step - loss: 9.2993e-06
# Epoch 29/50
# 27/27 [==============================] - 2s 79ms/step - loss: 6.3580e-06
# Epoch 30/50
# 27/27 [==============================] - 2s 86ms/step - loss: 7.9294e-06
# Epoch 31/50
# 27/27 [==============================] - 2s 85ms/step - loss: 7.6514e-06
# Epoch 32/50
# 27/27 [==============================] - 2s 86ms/step - loss: 6.2451e-06
# Epoch 33/50
# 27/27 [==============================] - 2s 89ms/step - loss: 7.8102e-06
# Epoch 34/50
# 27/27 [==============================] - 2s 85ms/step - loss: 8.0567e-06
# Epoch 35/50
# 27/27 [==============================] - 2s 75ms/step - loss: 5.7968e-06
# Epoch 36/50
# 27/27 [==============================] - 2s 75ms/step - loss: 1.2355e-05
# Epoch 37/50
# 27/27 [==============================] - 2s 84ms/step - loss: 7.4296e-06
# Epoch 38/50
# 27/27 [==============================] - 2s 86ms/step - loss: 1.0032e-05
# Epoch 39/50
# 27/27 [==============================] - 3s 96ms/step - loss: 1.6886e-05
# Epoch 40/50
# 27/27 [==============================] - 3s 94ms/step - loss: 8.0020e-06
# Epoch 41/50
# 27/27 [==============================] - 2s 84ms/step - loss: 4.1773e-06
# Epoch 42/50
# 27/27 [==============================] - 2s 77ms/step - loss: 9.2739e-06
# Epoch 43/50
# 27/27 [==============================] - 2s 75ms/step - loss: 8.3843e-06
# Epoch 44/50
# 27/27 [==============================] - 2s 84ms/step - loss: 6.9826e-06
# Epoch 45/50
# 27/27 [==============================] - 2s 84ms/step - loss: 4.9764e-06
# Epoch 46/50
# 27/27 [==============================] - 2s 84ms/step - loss: 6.5012e-06
# Epoch 47/50
# 27/27 [==============================] - 2s 85ms/step - loss: 6.3794e-06
# Epoch 48/50
# 27/27 [==============================] - 2s 85ms/step - loss: 1.2463e-05
# Epoch 49/50
# 27/27 [==============================] - 2s 78ms/step - loss: 9.0283e-06
# Epoch 50/50
# 27/27 [==============================] - 2s 71ms/step - loss: 8.0519e-06

# %%
#Prediction and visualization
real_confirmed_cases = arranged_dataset.iloc[170:213,0:1].values

X_test = []

for i in range(170,213):
    X_test.append(training_set_scaled[i-45:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_confirmed_cases = regressor.predict(X_test)
predicted_confirmed_cases = sc.inverse_transform(predicted_confirmed_cases)
# Out:
# 2/2 [==============================] - 5s 36ms/step

# %%
plt.figure(figsize = (12,8))
plt.plot(real_confirmed_cases, color='c',marker = 'o', label = 'Real Confirmed Cases')
plt.plot(predicted_confirmed_cases, color='g',marker = 'o', label = 'Predicted Number of Cases')
plt.title('Coronavirus Forecasting Trend in Cases')
#        3/6/21    3/7/21    3/8/21    3/9/21   3/10/21   3/11/21   3/12/21  \
# 251  29023931  29064938  29109974  29167616  29225536  29288010  29349533
#
#       3/13/21   3/14/21   3/15/21   3/16/21   3/17/21   3/18/21   3/19/21  \
# 251  29402465  29440686  29497352  29551309  29610445  29670983  29732612
#
#       3/20/21   3/21/21   3/22/21   3/23/21   3/24/21   3/25/21   3/26/21  \
# 251  29787986  29821754  29873347  29926950  30013910  30081375  30158696
#
#       3/27/21   3/28/21   3/29/21   3/30/21   3/31/21    4/1/21    4/2/21  \
# 251  30221396  30264493  30333922  30395171  30462210  30541255  30611086
#
#        4/3/21    4/4/21    4/5/21    4/6/21    4/7/21    4/8/21    4/9/21  \
# 251  30674153  30709125  30786804  30847348  30922386  31002264  31084962
#
#       4/10/21   4/11/21   4/12/21   4/13/21   4/14/21   4/15/21   4/16/21  \
# 251  31151497  31197877  31268107  31345985  31421360  31495649  31575640
#
#       4/17/21   4/18/21   4/19/21   4/20/21   4/21/21   4/22/21   4/23/21  \
# 251  31628013  31670031  31737964  31799237  31862094  31929351  31991750
#
#       4/24/21   4/25/21   4/26/21   4/27/21   4/28/21   4/29/21   4/30/21  \
# 251  32045113  32077178  32124869  32175725  32230850  32289049  32346971
#
#        5/1/21    5/2/21    5/3/21    5/4/21    5/5/21    5/6/21    5/7/21  \
# 251  32392274  32421641  32472201  32512934  32557669  32605183  32652472
#
#        5/8/21    5/9/21   5/10/21   5/11/21   5/12/21   5/13/21   5/14/21  \
# 251  32686965  32708357  32745255  32778906  32814784  32852871  32895169
#
#       5/15/21   5/16/21   5/17/21   5/18/21   5/19/21   5/20/21   5/21/21  \
# 251  32923982  32940846  32969512  32997331  33026624  33056765  33085106
#
#       5/22/21   5/23/21   5/24/21   5/25/21   5/26/21   5/27/21   5/28/21  \
# 251  33104884  33117737  33143662  33166418  33190470  33217995  33239963
#
#       5/29/21
# 251  33251939

# %%
us_covid_data = us_covid_data.drop(columns=['Province/State', 'Country/Region', 'Lat', 'Long'])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(us_covid_data.values.T)
us_covid_data = scaler.transform(us_covid_data.values.T)

# %%
import numpy as np

X, y = [], []
time_steps = 30

for i in range(len(us_covid_data) - time_steps):
    x = us_covid_data[i:(i+time_steps), 0]
    X.append(x)
    y.append(us_covid_data[i+time_steps, 0])

X = np.array(X)
y = np.array(y)

# %%
split = int(len(X) * 0.8)

X_train = X[:split]
X_test = X[split:]
y_train = y[:split]
y_test = y[split:]

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Input, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop

model = Sequential()
model.add(Input(shape=(1, time_steps)))
model.add(LSTM(48, return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(48, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(48))
model.add(Dropout(0.2))
model.add(Dense(1, activation='relu'))


model.compile(loss = 'mean_squared_error',
              optimizer = RMSprop(),
              metrics = ['mean_squared_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 48)             15168
#
#  dropout_4 (Dropout)         (None, 1, 48)             0
#
#  lstm_5 (LSTM)               (None, 1, 48)             18624
#
#  dropout_5 (Dropout)         (None, 1, 48)             0
#
#  lstm_6 (LSTM)               (None, 48)                18624
#
#  dropout_6 (Dropout)         (None, 48)                0
#
#  dense_1 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 52,465
# Trainable params: 52,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau

batchsize = 100
epochs =  100

learning_rate_reduction = ReduceLROnPlateau(monitor='val_mean_squared_error', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=1e-10)

history = model.fit(X_train,
                    y_train,
                    batch_size=batchsize,
                    epochs=epochs,
                    validation_split=0.2,
                    shuffle=False,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/100
# 3/3 [==============================] - 22s 2s/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.4326 - val_mean_squared_error: 0.4326 - lr: 0.0010
# Epoch 2/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.3869 - val_mean_squared_error: 0.3869 - lr: 0.0010
# Epoch 3/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.3370 - val_mean_squared_error: 0.3370 - lr: 0.0010
# Epoch 4/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.2826 - val_mean_squared_error: 0.2826 - lr: 0.0010
# Epoch 5/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.2261 - val_mean_squared_error: 0.2261 - lr: 0.0010
# Epoch 6/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.1703 - val_mean_squared_error: 0.1703 - lr: 0.0010
# Epoch 7/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.1191 - val_mean_squared_error: 0.1191 - lr: 0.0010
# Epoch 8/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0759 - val_mean_squared_error: 0.0759 - lr: 0.0010
# Epoch 9/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0431 - val_mean_squared_error: 0.0431 - lr: 0.0010
# Epoch 10/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - lr: 0.0010
# Epoch 11/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - lr: 0.0010
# Epoch 12/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 0.0010
# Epoch 13/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 9.7037e-04 - val_mean_squared_error: 9.7037e-04 - lr: 0.0010
# Epoch 14/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 7.9860e-04 - val_mean_squared_error: 7.9860e-04 - lr: 0.0010
# Epoch 15/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 9.2472e-04 - val_mean_squared_error: 9.2472e-04 - lr: 0.0010
# Epoch 16/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - lr: 0.0010
# Epoch 17/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - lr: 0.0010
# Epoch 18/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 5.0000e-04
# Epoch 19/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - lr: 5.0000e-04
# Epoch 20/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - lr: 5.0000e-04
# Epoch 21/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - lr: 2.5000e-04
# Epoch 22/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - lr: 2.5000e-04
# Epoch 23/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - lr: 2.5000e-04
# Epoch 24/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - lr: 1.2500e-04
# Epoch 25/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - lr: 1.2500e-04
# Epoch 26/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - lr: 1.2500e-04
# Epoch 27/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - lr: 6.2500e-05
# Epoch 28/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - lr: 6.2500e-05
# Epoch 29/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 6.2500e-05
# Epoch 30/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - lr: 3.1250e-05
# Epoch 31/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - lr: 3.1250e-05
# Epoch 32/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 3.1250e-05
# Epoch 33/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 1.5625e-05
# Epoch 34/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.5625e-05
# Epoch 35/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 1.5625e-05
# Epoch 36/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 7.8125e-06
# Epoch 37/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - lr: 7.8125e-06
# Epoch 38/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 7.8125e-06
# Epoch 39/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.9063e-06
# Epoch 40/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.9063e-06
# Epoch 41/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.9063e-06
# Epoch 42/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9531e-06
# Epoch 43/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9531e-06
# Epoch 44/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9531e-06
# Epoch 45/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.7656e-07
# Epoch 46/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.7656e-07
# Epoch 47/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.7656e-07
# Epoch 48/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.8828e-07
# Epoch 49/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.8828e-07
# Epoch 50/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.8828e-07
# Epoch 51/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.4414e-07
# Epoch 52/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.4414e-07
# Epoch 53/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.4414e-07
# Epoch 54/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.2207e-07
# Epoch 55/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.2207e-07
# Epoch 56/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.2207e-07
# Epoch 57/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 6.1035e-08
# Epoch 58/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 6.1035e-08
# Epoch 59/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 6.1035e-08
# Epoch 60/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.0518e-08
# Epoch 61/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.0518e-08
# Epoch 62/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.0518e-08
# Epoch 63/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.5259e-08
# Epoch 64/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.5259e-08
# Epoch 65/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 65: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.5259e-08
# Epoch 66/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 7.6294e-09
# Epoch 67/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 7.6294e-09
# Epoch 68/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 7.6294e-09
# Epoch 69/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.8147e-09
# Epoch 70/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.8147e-09
# Epoch 71/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 3.8147e-09
# Epoch 72/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9073e-09
# Epoch 73/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9073e-09
# Epoch 74/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 74: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.9073e-09
# Epoch 75/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.5367e-10
# Epoch 76/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.5367e-10
# Epoch 77/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 77: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 9.5367e-10
# Epoch 78/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.7684e-10
# Epoch 79/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.7684e-10
# Epoch 80/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 80: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 4.7684e-10
# Epoch 81/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.3842e-10
# Epoch 82/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.3842e-10
# Epoch 83/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 2.3842e-10
# Epoch 84/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.1921e-10
# Epoch 85/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.1921e-10
# Epoch 86/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1e-10.
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.1921e-10
# Epoch 87/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 88/100
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 89/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 90/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 91/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 92/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 93/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 94/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 95/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 96/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 97/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 98/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 99/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10
# Epoch 100/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 1.0000e-10

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Model Error')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()
